# %% [markdown]
# word2vec_model (1. pretrained model exp (Google_news dataset).
#                 2. model trained with from scratch(used for new_dataset) )
# 1. skip_gram
# 2. CBOW

# %% [markdown]
# 1. word2vec convert every words to vec form in a fixed dimension so create huge matrix
# 2. but we want to convert every sentences into fixed dimension so we used Avg_word2Vec_model

# %%
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import gensim
from gensim.models import KeyedVectors

from gensim.models import word2vec

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
vec_king = wv['king']
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
wv.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824870109558105),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903800010681),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.5716364979743958),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409236907959),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
wv.most_similar('king')
# Out:
# [('kings', 0.7138046026229858),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864822864532471),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.543294370174408),
#  ('throne', 0.5422104597091675)]

# %%
wv.similarity('man','king')
# Out:
# 0.22942673

# %%
wv.similarity('html','programmer')
# Out:
# 0.25811526

# %%
vec = wv['king']-wv['man']-wv['women']
vec
# Out:
# array([-6.05468750e-02, -2.65136719e-01, -4.21752930e-02,  1.14746094e-01,
#        -3.34228516e-01,  2.68798828e-01,  4.23339844e-01, -8.55102539e-02,
#        -2.53906250e-02,  2.65144348e-01, -1.49902344e-01,  1.19140625e-01,
#        -2.16796875e-01, -6.68945312e-02, -3.60107422e-02, -3.62060547e-01,
#         2.46093750e-01, -6.87561035e-02,  2.21862793e-02,  1.19140625e-01,
#         4.31640625e-01,  7.90252686e-02,  1.43310547e-01,  7.50000000e-01,
#         1.82617188e-01,  2.24609375e-01,  8.78906250e-03, -3.78662109e-01,
#         9.86328125e-02,  1.91040039e-01, -6.00433350e-02, -4.95605469e-02,
#         3.62304688e-01,  6.07543945e-01, -1.85058594e-01, -2.69042969e-01,
#        -1.48925781e-01,  2.68554688e-01,  6.44531250e-02, -2.74414062e-01,
#         1.70166016e-01, -2.92480469e-01,  1.95312500e-02,  1.95129395e-01,
#         1.35375977e-01,  2.05078125e-01,  4.05273438e-02,  5.20019531e-02,
# ...
